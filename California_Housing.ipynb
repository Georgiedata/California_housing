# %%
 # This Project looks to determine, by prediction, the prices of house in California. The data has been downloaded coming 
 without headers as seen below.

# %%
import pandas as pd

# %%
cal_housing=pd.read_csv(r'C:\Users\George\Downloads\Cal_data\cal_housing.data', header=None)
cal_housing
# Out:
#             0      1     2       3       4       5       6       7         8
# 0     -122.23  37.88  41.0   880.0   129.0   322.0   126.0  8.3252  452600.0
# 1     -122.22  37.86  21.0  7099.0  1106.0  2401.0  1138.0  8.3014  358500.0
# 2     -122.24  37.85  52.0  1467.0   190.0   496.0   177.0  7.2574  352100.0
# 3     -122.25  37.85  52.0  1274.0   235.0   558.0   219.0  5.6431  341300.0
# 4     -122.25  37.85  52.0  1627.0   280.0   565.0   259.0  3.8462  342200.0
# ...       ...    ...   ...     ...     ...     ...     ...     ...       ...
# 20635 -121.09  39.48  25.0  1665.0   374.0   845.0   330.0  1.5603   78100.0
# 20636 -121.21  39.49  18.0   697.0   150.0   356.0   114.0  2.5568   77100.0
# 20637 -121.22  39.43  17.0  2254.0   485.0  1007.0   433.0  1.7000   92300.0
# 20638 -121.32  39.43  18.0  1860.0   409.0   741.0   349.0  1.8672   84700.0
# 20639 -121.24  39.37  16.0  2785.0   616.0  1387.0   530.0  2.3886   89400.0
#
# [20640 rows x 9 columns]

# %%
cal_housing.rename(columns = {0:'longitude', 
                       1:'latitude',
                              2:'housing_median_age',
                              3:'total_rooms',
                              4:'total_bedrooms',
                              5:'population', 
                              6:'households', 
                              7:'median_income',
                              8:'median_house_value',
                             9: 'ocean_proximity'}, 
            inplace = True)

cal_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
cal_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
cal_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
cal_housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.898014   1425.476744    499.539680       3.870671
# std        421.247906   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
cal_housing.hist(bins=50, figsize=(20,20))
plt.show()

# %%
import numpy as np

def split_train_test(data,test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data)* test_ratio)
    test_indices = shuffled_indices[test_set_size:]
    train_indices = shuffled_indices[:test_set_size]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(cal_housing, 0.2)
len(train_set)
# Out:
# 4128

# %%
len(test_set)
# Out:
# 16512

# %%
from zlib import crc32
def test_set_check(identifier, test_ratio):
    return crc32(np.int64(identifier)) & 0xffffffff < test_ratio *2**32

# %%
# This was to ensure that the id column where properly matched to each set.
def split_train_test_by_id(data, test_ratio, id_column):
    ids = data[id_column]
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
    return data.loc[~in_test_set], data.loc[in_test_set]

housing_with_id = cal_housing.reset_index() # Reset index to create 'index' column
train_set, test_set = split_train_test_by_id(housing_with_id, 0.2, "index") # Pass "index" as id_column

# %%
# The scikit learn lib through the train_test_split function helps split the dataset into training and test set
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(cal_housing, test_size=0.2, random_state=42)

# %%
cal_housing["income_cat"] = pd.cut(cal_housing["median_income"], bins=[0,1.5,3,4.5,6
                                   , np.inf], labels=[1,2,3,4,5])
cal_housing["income_cat"].hist()
# Out:
# <AxesSubplot:>

# %%
#The stratified Sampling ensures that the  sampple values picked is a credible representation of the whole.
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(cal_housing, cal_housing["income_cat"]):
    strata_test_set= cal_housing.loc[test_index]
    strata_train_set=cal_housing.loc[train_index]
strata_test_set["income_cat"].value_counts()/ len(strata_test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: income_cat, dtype: float64

# %%
for set_ in (strata_train_set, strata_test_set):
    set_.drop("income_cat", axis=1, inplace=True)
cal_housing = strata_train_set.copy()

# %%
cal_housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
cal_housing.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4, s=cal_housing["population"]/100, label='population', 
                 figsize=(8,7), c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True)
plt.legend()

# %%
h_corr = cal_housing.corr()
h_corr['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687151
# total_rooms           0.135140
# housing_median_age    0.114146
# households            0.064590
# total_bedrooms        0.048586
# population           -0.026882
# longitude            -0.047466
# latitude             -0.142673
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['median_house_value', 'median_income', 'total_rooms', 'housing_median_age']
scatter_matrix(cal_housing[attributes], figsize=(12, 9))
# Out:
# array([[<AxesSubplot:xlabel='median_house_value', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='median_house_value'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='median_house_value'>],
#        [<AxesSubplot:xlabel='median_house_value', ylabel='median_income'>,
#         <AxesSubplot:xlabel='median_income', ylabel='median_income'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='median_income'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='median_income'>],
#        [<AxesSubplot:xlabel='median_house_value', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='median_income', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='total_rooms', ylabel='total_rooms'>,
#         <AxesSubplot:xlabel='housing_median_age', ylabel='total_rooms'>],
#        [<AxesSubplot:xlabel='median_house_value', ylabel='housing_median_age'>,
# ...

# %%
# strong positive correlation between median_house_value and median_income
cal_housing.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>

# %%
# Here we find certain ratios that are relevant to the pricing

cal_housing["rooms_per_household"] = cal_housing["total_rooms"]/cal_housing["households"] 
cal_housing["bedroom_per_room"] = cal_housing["total_bedrooms"]/cal_housing["total_rooms"]
cal_housing["population_per_household"] = cal_housing["population"]/cal_housing["households"]
corr_matrix = cal_housing.corr()
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.687151
# rooms_per_household         0.146255
# total_rooms                 0.135140
# housing_median_age          0.114146
# households                  0.064590
# total_bedrooms              0.048586
# population_per_household   -0.021991
# population                 -0.026882
# longitude                  -0.047466
# latitude                   -0.142673
# bedroom_per_room           -0.259934
# Name: median_house_value, dtype: float64

# %%
# The train set is cleaned by dropping median house value and total bedrooms.
#Note we want to concentrate on training set first and make a copy of the dataset

housing = strata_train_set.drop("median_house_value", axis=1)
housing_labels=strata_train_set["median_house_value"].copy()
housing.drop("total_bedrooms", axis=1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 12655    -121.46     38.52                29.0       3873.0      2237.0
# 15502    -117.23     33.09                 7.0       5320.0      2015.0
# 2908     -119.04     35.37                44.0       1618.0       667.0
# 14053    -117.13     32.75                24.0       1877.0       898.0
# 20496    -118.70     34.28                27.0       3536.0      1837.0
# ...          ...       ...                 ...          ...         ...
# 15174    -117.07     33.03                14.0       6665.0      2026.0
# 12661    -121.42     38.51                15.0       7901.0      4769.0
# 19263    -122.72     38.44                48.0        707.0       458.0
# 19140    -122.70     38.31                14.0       3155.0      1208.0
# 19773    -122.14     39.97                27.0       1079.0       625.0
#
#        households  median_income
# 12655       706.0         2.1736
# 15502       768.0         6.3373
# ...

# %%
# Data cleaning using SimpleImputer function to replace missing values with median as it fits.
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
imputer.statistics_
# Out:
# array([-118.51   ,   34.26   ,   29.     , 2119.     ,  433.     ,
#        1164.     ,  408.     ,    3.54155])

# %%
housing.median().values
# Out:
# array([-118.51   ,   34.26   ,   29.     , 2119.     ,  433.     ,
#        1164.     ,  408.     ,    3.54155])

# %%
X = imputer.transform(housing)
housing_tr= pd.DataFrame(X, columns=housing.columns, index=housing.index)

# %%
rooms_ix, bedrooms_ix, population_ix, household_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room=True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        # Calculate additional attributes
        rooms_per_household = X[:, rooms_ix] / X[:, household_ix]
        population_per_household = X[:, population_ix] / X[:, household_ix]
        
        # Optionally add the bedrooms_per_room attribute
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room] #concat new atrributes into an a larger array
        else:
            return np.c_[X, rooms_per_household, population_per_household]

# Create an instance of the transformer
attr_adder = CombinedAttributesAdder(add_bedrooms_per_room=False)

# Now, use the transformer to transform your data (after fixing indentation)
# Assuming `housing` is a NumPy array or a Pandas DataFrame
housing_extra_attribs = attr_adder.transform(housing.values)

# %%
# Feature Scaling/ transformation pipeline

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
num_pipeline = Pipeline([
 ('imputer', SimpleImputer(strategy="median")),
 ('attribs_adder', CombinedAttributesAdder()),
 ('std_scaler', StandardScaler()),
 ])
housing_num_tr=num_pipeline.fit_transform(housing)

# %%
from sklearn.compose import ColumnTransformer

num_attribs = list(housing)
full_pipeline = ColumnTransformer([('num',num_pipeline, num_attribs)])
housing_prep = full_pipeline.fit_transform(housing)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(housing_prep, housing_labels)
some_data=housing.iloc[:5]
some_labels=housing_labels.iloc[:5]
some_data_prep=full_pipeline.transform(some_data)

"Predictions:",lin_reg.predict(some_data_prep)
# Out:
# ('Predictions:',
#  array([116024.81964384, 332258.00105752, 160789.04306783, 174885.38739682,
#         251069.36069202]))

# %%
"Labels:", list(some_labels)
# Out:
# ('Labels:', [72100.0, 279600.0, 82700.0, 112500.0, 238300.0])

# %%
 from sklearn.metrics import mean_squared_error
housing_predictions = lin_reg.predict(housing_prep)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 68809.73788221365

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_prep, housing_labels)
housing_prediction = tree_reg.predict(housing_prep)
tree_mse = mean_squared_error(housing_labels, housing_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_mse
# Out:
# 4734780027.418949

# %%
 from sklearn.model_selection import cross_val_score
 scores = cross_val_score(tree_reg, housing_prep, housing_labels,
 scoring="neg_mean_squared_error", cv=10)
 tree_rmse_scores = np.sqrt(-scores)

# %%
 def display_scores(scores):
      
    print("Scores:", scores)
      
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
 
    display_scores(tree_rmse_scores)
# Out:
# Scores: [78893.15041396 74275.00847486 71231.4400265  74835.10468978
#  72797.40969589 76080.47264762 71730.51252135 73390.48321529
#  70369.86013763 74965.8418749 ]
# Mean: 73856.92836977946
# Standard deviation: 2399.6587224482228

# %%
lin_scores = cross_val_score(lin_reg, housing_prep, housing_labels,
                               
scoring="neg_mean_squared_error", cv=10)

lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [71696.91641028 64487.04864858 68470.47577505 68649.50655168
#  67568.08941419 72728.10601052 71188.71645754 69118.16317946
#  66540.60914732 70534.09128858]
# Mean: 69098.17228832017
# Standard deviation: 2389.6145227294614

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(housing_prep, housing_labels)
forest_mse = mean_squared_error(housing_labels, housing_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 68809.73788221365

# %%
 display_scores(forest_rmse)
# Out:
# Scores: 68809.73788221365
# Mean: 68809.73788221365
# Standard deviation: 0.0
